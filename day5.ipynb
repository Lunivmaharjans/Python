# %%
def add(a,b): #modules
    return a + b;

def mult (a,b):
    return a*b;

def sub(a,b):
    return a + b;

def div(a,b):
    return a + b;

# %%
try:
    num = int(input("enter a number"))
    print(1/num)
except ZeroDivisionError:
    print("cannot divided by zero")
except ValueError:
    print("that was not a valid input")
except Exception as e:
    print("Unhandle Error", e)
finally:
    print("hello")
# Out:
# Unhandle Error division by zero

# %%
#dunbor valurable
#example __luniv__
