# %%
a = int(input("enter a number"))

if a % 2 == 0:
    print("it is even")
else:
    print("it is odd")

# %%
if a <= 1:
    print("The number is not Prime")
else:
    for i in range(2, a):
        if a % i == 0:
            print("The number is not Prime")
            break
    else:
        print("The number is Prime")

# %%
a = abs(a)

sum_digits = 0


while a > 0:
    digit = a % 10
    sum_digits += digit
    a = a // 10

print("Sum of digits =", sum_digits)

# %%
data = [12, -3, 45, 0, -8, 23, 45, 12]

# %%
postive_data = list(filter(lambda something : something >=0 , data))
print(postive_data)

# %%
du_data = []
x = []
for x in postive_data:
    if x not in du_data:
        du_data.append(x)

x = list.copy(data)

print(du_data)
print(x)

# for x in postive_data:
#     if x in du_data:
#         pass
#     else:
#         du_data.append(x)

# print(du_data)

# %%
max_data = max(data)
min_data = min(data)
max_posdata = max(postive_data)
min_posdata = min(postive_data)
print(max_data)
print(min_data)
print(max_posdata)
print(min_posdata)

# %%
second_largest = []
du_data.sort()
second_largest = du_data[-2]
print(second_largest)

# %%
s = input("Enter string: ")

result = ""
count = 1

for i in range(len(s)):
    if i < len(s) - 1 and s[i] == s[i + 1]:
        count += 1
    else:
        result += s[i] + str(count)
        count = 1  

print("Compressed string:", result)

# %%
def calculate_result(marks):
    avg = sum(marks)/len(marks)
    if avg >= 80:
        grade= "A"
    elif avg >=60:
        grade="B"
    elif avg >= 40:
        grade="C"
    else:
        grade="F"
    
    return avg, grade 

student = {}

num = int(input("enter the no of student"))

for i in range (num):
    name = input("Enter student name: ")        
    marks = []

    print("enter the marks of Subject")
    for j in range(3):
        mak = int(input())
        marks.append(mak)
    student[mak] = marks

for name, marks in student.items():
    avg , grade = calculate_result(marks)    

    print("\n Name:",name)
    print("\n Marks:",marks)
    print("\n Average",avg)
    print("\n Grade",grade)

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)
xa = numpy.median(speed)


print(x)
print(xa)
# Out:
# 87.0

# %%
import numpy

x = numpy.random.uniform(0.0, 5.0, 10)

print(x)

# %%
import numpy as np

arr = np.linspace(0, 5, 10)
print(arr)

# %%
import numpy as np
import matplotlib.pyplot  as plt

# %%
x= np.linspace(0,2*np.pi, 200)
y= np.sin(x)

fig , ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x1 = np.linspace(0,50,100)
y1 = np.random.rand(100)

fig,ax = plt.subplots()
ax.scatter(x1,y1)
plt.show()

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.plot(x,y)
plt.title("random scatter plot")

plt.show()

# %%
years =["2021","2022","2023","2024"]
gdp = [1000,1010,900,1400]

plt.bar(years,gdp)
plt.show()

# %%
x = np.linspace(0,50,60)
random_noise = np.random.rand(60)
y = 3 * x + random_noise
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,10)
y = x ** 2

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-10,11)
y = x ** 2

plt.plot(x,y)
plt.show()

# %%
r = 5
ci = np.linspace(0,2*np.pi,200)
x = r *np.cos(ci)
y = r *np.sin(ci)

plt.plot(x,y)
plt.axis('equal')
plt.show()

# %%
x = np.linspace(-10, 10, 400)

# avoid invalid values inside sqrt
x = x[np.abs(x) > 1]

y = np.sqrt(x**2 - 1)

plt.plot(x, y)
plt.plot(x, -y)

plt.axhline(0)
plt.axvline(0)

plt.show()

# %%
x = np.linspace(0,50,60)
random_noise=np.random.rand(60)
y=3 * x + random_noise * 10
y2= 2.9* x + 7

plt.plot(x,y2)
plt.scatter(x,y)
plt.xlim((0,50))
plt.ylim((0,200))
plt. show()
