# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
new_YearsExperience = np.array(df['YearsExperience']).reshape(-1, 1)
new_Salary = np.array(df['Salary']).reshape(-1, 1)
type(new_YearsExperience), type(new_Salary)
new_YearsExperience.shape, new_Salary.shape
# Out:
# ((30, 1), (30, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
type(new_Salary)
# Out:
# numpy.ndarray

# %%
# nu = np.array(X)
# na = np.array(y)
# print(nu)
# print(type(nu))
# nu.shape
# Out:
# [ 1.2  1.4  1.6  2.1  2.3  3.   3.1  3.3  3.3  3.8  4.   4.1  4.1  4.2
#   4.6  5.   5.2  5.4  6.   6.1  6.9  7.2  8.   8.3  8.8  9.1  9.6  9.7
#  10.4 10.6]
# <class 'numpy.ndarray'>
# (30,)

# %%
x = new_YearsExperience
y = new_Salary

# %%
model = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(new_YearsExperience,new_Salary,test_size=0.33)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color = "red")
plt.xlabel("Year")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = model.predict(X_test)
print(y_pred,y_test)
# Out:
# [[ 64877.52811008]
#  [124816.47110362]
#  [ 82671.90181129]
#  [ 63004.43614153]
#  [122943.37913507]
#  [110768.28133951]
#  [ 68623.71204718]
#  [ 63940.98212581]
#  [103275.91346532]
#  [ 53638.97629879]] [[ 57082.]
#  [121873.]
#  [ 93941.]
#  [ 63219.]
#  [122392.]
#  [105583.]
#  [ 61112.]
#  [ 55795.]
#  [113813.]
#  [ 56643.]]

# %%
mae = mean_absolute_error(y_test,y_pred)
mae = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
df = pd.read_csv("framingham.csv")

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.drop(columns=['education'], inplace=True)

# %%
df = df.drop(['glucose', 'TenYearCHD'])
