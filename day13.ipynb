# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = sns.load_dataset("tips")

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df['total_bill'] - df['tip']
# Out:
# 0      15.98
# 1       8.68
# 2      17.51
# 3      20.37
# 4      20.98
#        ...
# 239    23.11
# 240    25.18
# 241    20.67
# 242    16.07
# 243    15.78
# Length: 244, dtype: float64

# %%
df['tip'].mean()
# Out:
# np.float64(2.99827868852459)

# %%
df["test"] = np.arange(0,244)

# %%
df["tips_percentage"] = ((df['tip'] / df['total_bill']) * 100)

# %%
df.drop(columns=['test'],inplace=True)

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_percentage
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2        41.666667
# 153       24.55  2.00    Male     No   Sun  Dinner     4         8.146640
# 146       18.64  1.36  Female     No  Thur   Lunch     3         7.296137
# 195        7.56  1.44    Male     No  Thur   Lunch     2        19.047619
# 75        10.51  1.25    Male     No   Sat  Dinner     2        11.893435

# %%
tip_per = df['tips_percentage'].to_numpy()
np.mean(tip_per)
np.median(tip_per)
np.std(tip_per)
np.max(tip_per)
np.min(tip_per)
# Out:
# np.float64(3.563813585135547)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
size = df["size"]
tip_per = df["tips_percentage"]
sns.scatterplot(x=size, y=tip_per)
# Out:
# <Axes: xlabel='size', ylabel='tips_percentage'>

# %%
bill = df["total_bill"]
tip_per = df["tips_percentage"]
sns.scatterplot(x=bill, y=tip_per)
# Out:
# <Axes: xlabel='total_bill', ylabel='tips_percentage'>

# %%
mean_tip = df["tip"].mean()
mean_tip
# Out:
# np.float64(2.99827868852459)

# %%
df[df["tip"] > 1].shape
# Out:
# (240, 8)

# %%
df.shape
# Out:
# (244, 8)

# %%
above_avg = df[df["tip"] > mean_tip]
above_avg
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_percentage
# 2         21.01  3.50    Male     No   Sun  Dinner     3        16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2        13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4        14.680765
# 5         25.29  4.71    Male     No   Sun  Dinner     4        18.623962
# 7         26.88  3.12    Male     No   Sun  Dinner     4        11.607143
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2        29.198966
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2        19.317450
# 238       35.83  4.67  Female     No   Sat  Dinner     3        13.033771
# 239       29.03  5.92    Male     No   Sat  Dinner     3        20.392697
# 243       18.78  3.00  Female     No  Thur  Dinner     2        15.974441
#
# [121 rows x 8 columns]

# %%
sns.histplot(df['total_bill'],bins= 30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df.groupby("day")["tips_percentage"].mean()
# Out:
# day
# Thur    16.127563
# Fri     16.991303
# Sat     15.315172
# Sun     16.689729
# Name: tips_percentage, dtype: float64

# %%
smoke_group = df.groupby("smoker")["tips_percentage"].mean()
smoke_group
# Out:
# smoker
# Yes    16.319604
# No     15.932846
# Name: tips_percentage, dtype: float64

# %%
sns.histplot(df["day"], bins=20)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
day = df["day"]
above_avg = df[df["tip"] > mean_tip]
    

sns.barplot(x=day, y=above_avg["tip"])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
day_vs_rev = df.groupby("day")['total_bill'].sum()
# dir(day_vs_rev)
# print(day_vs_rev)
# print(day_vs_rev.values)
# print(day_vs_rev.index)

sns.barplot(x = day_vs_rev.index, y =day_vs_rev.values)
# Out:
# <Axes: xlabel='day'>

# %%
df['is_weekend'] = df["day"].isin(['Sat', 'Sun']) #bool ma aaudai xa
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3        16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3        16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2        13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4        14.680765
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2         9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2        15.974441
#
#      is_weekend
# 0          True
# 1          True
# 2          True
# ...

# %%
df.drop(columns=["day"],inplace=True)

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker    time  size  tips_percentage  \
# 236       12.60  1.00    Male    Yes  Dinner     2         7.936508
# 202       13.00  2.00  Female    Yes   Lunch     2        15.384615
# 70        12.02  1.97    Male     No  Dinner     2        16.389351
# 230       24.01  2.00    Male    Yes  Dinner     4         8.329863
# 11        35.26  5.00  Female     No  Dinner     4        14.180374
#
#      is_weekend
# 236        True
# 202       False
# 70         True
# 230        True
# 11         True
