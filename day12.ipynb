# %%
import subprocess
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sas

# %%
x = np.arange(-10,10)
y = x**2
sas.lineplot(x=x,y=y)
plt.show()

# %%
x = np.random.rand(1000)

sas.boxplot(x=data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 x = np.random.rand(1000)
#       2
# ----> 3 sas.displot(x.poisson(lam=2, size=1000))
#       4
#       5 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'poisson'

# %%
data = np.random.randn(5,5)
print(data)
sas.heatmap(data)
plt.show()
# Out:
# [[ 0.84580528  1.39240713  0.12124025  0.15770524 -0.54124627]
#  [-0.01382534  0.942189   -0.16116926 -0.55535096 -0.89408332]
#  [ 0.46958463 -0.00342406 -1.15973754  0.92755179 -1.5779055 ]
#  [-0.24518797  1.59509512 -0.91337944  1.26052438 -0.74926662]
#  [-1.28128503  0.73118621  0.61079138  0.12011212 -2.0862566 ]]

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
import pandas as pd
data = {
    "name" : ["luniv", "Prashant", "lunia"],
    "marks" : [49, 45, 54]
}

df = pd.DataFrame(data)
print(df)
# Out:
#        name  marks
# 0     luniv     49
# 1  Prashant     45
# 2     lunia     54

# %%
df = pd.read_csv("data.csv")
print(df.tail())
# Out:
#              x          y
# 995  17.726727  46.571407
# 996  49.429735  91.084734
# 997   1.318091  16.927206
# 998  18.455390  50.270771
# 999   4.357072  -9.202795

# %%
df.columns
# Out:
# Index(['x', 'y'], dtype='str')

# %%
print(df['y'])
print(df['x'])
# Out:
# 0      128.780163
# 1       37.624932
# 2       15.559688
# 3       97.565079
# 4       14.252318
#           ...
# 995     46.571407
# 996     91.084734
# 997     16.927206
# 998     50.270771
# 999     -9.202795
# Name: y, Length: 1000, dtype: float64
# 0      48.956625
# 1      17.236877
# 2      13.502657
# 3      44.543399
# 4       2.434103
#          ...
# 995    17.726727
# 996    49.429735
# 997     1.318091
# 998    18.455390
# 999     4.357072
# Name: x, Length: 1000, dtype: float64

# %%
df = pd.read_csv("data.csv")
print(df.head(100))
df.plot.scatter(x='x' , y = 'y')
plt.show()
# Out:
#             x           y
# 0   48.956625  128.780163
# 1   17.236877   37.624932
# 2   13.502657   15.559688
# 3   44.543399   97.565079
# 4    2.434103   14.252318
# ..        ...         ...
# 95   2.135137   22.824073
# 96  25.825041   72.752609
# 97  10.400026  -11.438359
# 98  21.615509   53.720856
# 99   3.889274   -6.123362
#
# [100 rows x 2 columns]
