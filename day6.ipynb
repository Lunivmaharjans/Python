# %% [markdown]
# OOP In Python
# -abstarction encapsulation inheritance polymorphism

# %%
#OOP

student_name = "Luniv"
student_rollno = 11
student_marks = (60,70,80)

student_name = "Luniv"
student_rollno = 12
student_marks = (60,70,80)

student_name = "Luniv"
student_rollno = 13
student_marks = (60,70,80)

# %%
student_1 = {
    "name" : "luniv" ,
    "rollno" : 1 ,
    "marks" : [40,50,60]
}

# %%
student_1_name = ["luniv", "anurag"]
student_rollno = [16,21]
student_1_marks = [40,50,60]

student_2_name = ["luniv", "anurag"]
student_rollno = [16,21]
student_2_marks = [40,50,60]

# %%
def calculator_avg(marks ):
    return sum(marks)/len(marks)

student_1_avg = calculator_avg(student_1_marks)
student_2_avg = calculator_avg(student_2_marks)

# %%
# def calculate_avg_2(student):
#     return sum(student("marks"))/len(student("marks"))

# student_1 = calculate_avg_2(student_1)
# print(student_1_avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 def calculate_avg_2(student):
#       2     return sum(student("marks"))/len(student("marks"))
#       3
# ----> 4 student_1 = calculate_avg_2(student_1)
#       5 print(student_1_avg)
#
# Cell In[5], line 2, in calculate_avg_2(student)
#       1 def calculate_avg_2(student):
# ----> 2     return sum(student("marks"))/len(student("marks"))
#
# TypeError: 'dict' object is not callable

# %%
# def calculate_avg_3(mark):
#     return sum(mark)/len(mark)

# student_1_ag = calculate_avg_3(student_2_mark[0])

# print(student_1_name[0],student_1_ag)
